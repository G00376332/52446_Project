# %% [markdown]
# # <center>Fundamentals of Data Analysis Project - Tips Dataset</center>
#
# <p align="center"> <img width="400" height="400" src="Pictures/tip1.png" alt="Choice Function Description" /> </p>

# %% [markdown]
# ###  Table of Contents<a id="table"/>
#
# * [Goals and objectives](#goals)
# * [About the Tips Dataset](#about-dataset)
# * [Dataset review](#dataset-review)
#  * [Description](#description)
#  * [Statistical data review](#statistical)
#  * [Data visualisation](#visualisation)
# * [Regression](#regression)
# * [Analyse](#analyse)
# * [Summary](#summary)
# * [References](#references)

# %% [markdown]
# ## Goals and objectives<a id="goals"/>

# %% [markdown]
# * Research nad investigate tips dataset
# * Use Jupyter notebook and Seaborn with descriptive statistics and plots to describe dataset
# * Discusse and analyse the relationship between the total bill and tip amount
# * Analyse the relationship between the variables within the dataset
# * Conclusion and summary about research and findings

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ## About the Tips Dataset<a id="about-dataset"/>

# %% [markdown]
# Tips dataset is one of the fundamental portions of data which is widely used in Python and machine learning. The history behind this dataset is that one waiter form one restaurant in the USA recorded information about each tip he received over a period of a few months of his work. The restaurant, located in a suburban shopping mall, was part of a national chain and served a varied menu. In observance of local law, the restaurant offered to seat in a non-smoking section to guests who requested it. Each record includes a day and time, and taken together, they show the waiter’s work schedule.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ## Dataset review<a id="dataset-review"/>

# %% [markdown]
# To begin with, dataset research is necessary to upload tips dataset into the python and allow by using appropriate libraries and tools to analyse all data. There are two ways to start working in python with this dataset:
# * dataset can be downloaded locally into the repository (the folder called Dataset was created for this purpose) and then by using read function from pandas library get all data available for further manipulation or analysis
# * using Seaborn module which has a built-in set of different datasets where one of it is tips dataset

# %%
# Import all necessary libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# To keep some of seaborn plotting warning off
import warnings 
warnings.filterwarnings("ignore") 

# Use magic function to render the figure in a notebook
# %matplotlib inline

# Using pandas and read_cvs function load dataset from local folder - method 1
df = pd.read_csv("Dataset/tips.csv")

# Using seaborn load tips dataset from its built-in datasets - method 2
tipsdata = sns.load_dataset("tips")

# %% [markdown]
# Looking at the above two methods it can be clearly seen that no matter what method was used to load dataset the outcome results are the same.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ### Description<a id="description"/>

# %% [markdown]
# Having dataset loaded it is possible now to start using descriptive statistics and plots to describe tips dataset.
# At the beginning is important to understand what exact data are inside.
#
# There are separate commands to display shape or a certain portion of data from the beginning and end of the dataset.
# It is a good practice to display first few, and last rows of unknown data to quickly review what is in it and if there are no strange characters that can cause an issue with further data manipulation.

# %%
# Display the shape of the dataset
tipsdata.shape
# Out:
# (244, 7)

# %%
# Display the head of the dataset
tipsdata.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Display the tail of the dataset
tipsdata.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# By looking at outputs the head and tail of dataset is visible. Tips dataset contains 244 rows and 7 column of data.
# Columns contain following variables:
#
# * total_bill
# * tip
# * sex
# * smoker
# * day
# * time
# * size

# %% [markdown]
# It is easy to notice what kind of data types are inside the dataset but pandas has function **data.dtypes** to determine this.

# %%
# Check what kind of variables are inside
tipsdata.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# From the output it can be seen that there are categorical and numerical variables.
#
# Categorical variables take on values that are names or labels. The color of a ball (e.g., red, green, blue) or the breed of a dog (e.g., collie, shepherd, terrier) would be examples of categorical variables.
#
# In this case the categorical variables are:
#
# * sex
# * smoker
# * day
# * time
#
# Quantitative variables are numerical. They represent a measurable quantity like counts, percents, or numbers.
#
# Tips dataset numerical variables are:
#
# * total_bill
# * tip
# * size

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ### Statistical data review<a id="statistical"/>

# %% [markdown]
# Because it became clear what type of data are inside, it is time to do some basic statistical summary on the dataset.
# Very useful function to do this is **describe**.

# %%
# Display basic statistical summary of the dataset
tipsdata.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Display the mean of the dataset
tipsdata.mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %% [markdown]
# The above table gathered the standard statistical data.
# Having above short summary it's time to find some relationship between variables. The right way is to plot data to see how those data can be nicly presented and if it is possible to find some corelations between them.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ### Data visualisation<a id="visualisation"/>

# %% [markdown]
# In previous section it was revealed that dataset contains categorical data. For that purpose **Seaborn** is perfect tool to works with visualization of those kind of data. The Seaborn is is complimentary to Matplotlib and it specifically targets statistical data visualization. In seaborn, there are several different ways to visualize a relationship involving categorical data. There are three different types of plots families:
#
# * Categorical scatterplots
# * Categorical distribution plots
# * Categorical estimate plots
#
# These above types represent the data using different levels of granularity. To pick the appropriate plot it is necessary to know what question should be answered.

# %% [markdown]
# Let's start with simple data presentation and plots numerical data distributions to visualize findings in statistical summary.

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(20,10))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Creates a  chart with total_bill data
plt.subplot(1,3,1)
# Add title to the chart
plt.title("Total Bill", fontweight="bold", fontsize=15)
# Use Seaborn displot distribution
sns.distplot(tipsdata["total_bill"])

# Creates a  chart with tip data
plt.subplot(1,3,2)
# Add title to the chart
plt.title("Tip", fontweight="bold", fontsize=15)
# Use Seaborn displot distribution
sns.distplot(tipsdata["tip"], color="g")

# Creates a  chart with number of guests data
plt.subplot(1,3,3)
# Add title to the chart
plt.title("Size", fontweight="bold", fontsize=15)
# Use Seaborn displot distribution
sns.distplot(tipsdata["size"], color="r")

plt.show()

# %% [markdown]
#  The above plots nicely illustrate all summary figures from numerical review. The most bills value was in the range between 10 and 20. The biggest value group for tips was in area 2 and 4 and the most frequent group size of guests was around 2.

# %% [markdown]
# To add more to the investigation of this dataset and use remaining non-numerical data other categorical plots will be used.

# %% [markdown]
# #### Boxplot

# %% [markdown]
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. It can give all the stats provided in dataset .describe in a single plot. If the dataset is too large and the range of value is too big then it shows some values as outliers based on an inter-quartile function.
#
# <p align="center"> <img width="400" height="400" src="Pictures/boxplot.png" alt="Choice Function Description" /> </p>

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(16,5))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Creates a  chart with total_bill vs. day 
plt.subplot(1,3,1)
# Add title to the chart
plt.title("Day vs.Total Bill", fontweight="bold", fontsize=15)
# Use Seaborn boxplot to display boxplot
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tipsdata, palette="PuRd_r")

# Creates a  chart with total_bill vs. day and sex
plt.subplot(1,3,2)
# Add title to the chart
plt.title("Sex vs.Tip", fontweight="bold", fontsize=15)
# Use Seaborn boxplot to display boxplot
sns.boxplot(x="sex", y="tip", hue="smoker", data=tipsdata, palette="PuRd_r")

# Creates a  chart with total_bill vs. day and smoker
plt.subplot(1,3,3)
# Add title to the chart
plt.title("Sex vs.Total Bill", fontweight="bold", fontsize=15)
# Use Seaborn boxplot to display boxplot
sns.boxplot(x="sex", y="total_bill", hue="smoker", data=tipsdata, palette="PuRd_r")

plt.show()

# %% [markdown]
# The box represents the values between 25-quartile and 75-quartile. The horizontal line in the box shows the median. Two horizontal lines at the bottom and at the top represent the minimum, and the maximum value respectively. The dots represent the outliers calculated based on the inter-quartile function. Using these plots is possible to compare values for different categories in a single graph.
#
# Putting a few charts with different configurations of variables side by side is a convenient way to see first correlations between them.
# In this case, is very easy to see that males paying higher bills than females and accordingly leaving higher tips. It is also not difficult to claim that smokers in both groups paying and tipping more. In respect of days, bills are higher during the weekend.

# %% [markdown]
# #### Violin Plot

# %% [markdown]
# Violin plots allow to visualize the distribution of a numeric variable for one or several groups. It is really close from a boxplot, but allows a deeper understanding of the density. Violins are particularly adapted when the amount of data is huge and showing individual observations gets impossible. This graph is one of the best and convenient way of data presentation. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. The black bar in the centre of each figure is related to the interquartile range.
#
# <p align="center"> <img width="400" height=400" src="Pictures/violin.png" alt="Violin Plot" /> </p>

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(16,5))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Use Seaborn violinplot to draw violin plot
sns.violinplot(x="day", y="total_bill", hue="time", palette="husl", data=tipsdata)
plt.show()

# %% [markdown]
# A quick look at presented violin plot shows that there was only one dinner on Thursday and there were no data for lunch during the weekend.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ### Regression<a id="regression"/>

# %% [markdown]
# This section will focus on evaluating whether there is any relationship between the total bill and tip amount in the dataset.

# %% [markdown]
# #### Investigation and correlation

# %% [markdown]
# At the beginning is good to see what correlation is between numerical variables. Pandas **dataframe.corr()** is used to find the pairwise correlation of all columns in the dataframe. For any non-numeric data type columns in the dataframe it is ignored.

# %%
# Use corr() function to check correlation between data
tipsdata.corr(method ="pearson")
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# The correlation of a variable with itself is 1 that's why diagonal values are 1. The results show that total_bill correlation to the tip using pearson method is **0.676** and is higher compare to size. It looks like the strogest corelation in numerical variables of dataset is between total_bill and tip amount.

# %%
# Create new dataset with correlation of variables of tips dataset
datacorr = tipsdata.corr()

# Defines axes font and lable size 
sns.set_context("paper", font_scale=2)

# Defines chart size
f, ax = plt.subplots(figsize =(9, 8)) 
# Show data correlation on heatmap plot
sns.heatmap(datacorr, ax = ax, cmap ="Set1_r", linewidths = 0.1) 
plt.show()

# %% [markdown]
# The above heatmap plot illustrates data correlation in a straight and clear format.

# %% [markdown]
# Talking about tip is worth to think about informal rules around the world regarding bill and gratuity.
# In Europe, there is quite a freedom with tipping. If there is no formal obligation or information in the menu that service charge will apply it is goodwill of customer how big tip he leaves. In most Asian (Singapore, Malaysia etc.) countries the tip is automatically added to the final bill and is equal to 10 per cent of the final bill. There are some exceptions like Japan where people don't leave tip at all and in some places leaving tips could be offensive. These data were collected in the USA where gratuity culture is again slightly different.
# The waiter or waitress basic wages are a tiny and main part of their remuneration is coming from tips. That's why common practice in the US is always adding a tip around 10-20% to the bill where 15-20% is a standard tip. Based on this information is good to check what percentage part of the bill is a tip.

# %%
# Create data with tip in % to the bill
tipper = tipsdata["tip"]/tipsdata["total_bill"]*100
# Display main statistical data
tipper.describe()
# Out:
# count    244.000000
# mean      16.080258
# std        6.107220
# min        3.563814
# 25%       12.912736
# 50%       15.476977
# 75%       19.147549
# max       71.034483
# dtype: float64

# %%
# Insert tip% data column to tips dataset
tipsdata.insert(2,"tip%",tipsdata["tip"]/tipsdata["total_bill"]*100)
# Check if is correct
tipsdata.head()
# Out:
#    total_bill   tip       tip%     sex smoker  day    time  size
# 0       16.99  1.01   5.944673  Female     No  Sun  Dinner     2
# 1       10.34  1.66  16.054159    Male     No  Sun  Dinner     3
# 2       21.01  3.50  16.658734    Male     No  Sun  Dinner     3
# 3       23.68  3.31  13.978041    Male     No  Sun  Dinner     2
# 4       24.59  3.61  14.680765  Female     No  Sun  Dinner     4

# %%
# Defines chart size
plt.figure(figsize=(16,5))
# Display boxplot with tip% to visualise results
sns.boxplot(x="tip%", data=tipsdata, palette="gist_rainbow")
plt.show()

# %% [markdown]
# The results are quite obvious. The boxplot and statistical data show that average percentage of the tip was over **16%** with few outliers like max tip over 70%. The rule mentioned at the beginning of this section about the tip in the US can be acknowledged true. Most customers are leaving tip in the range between 15-20% with a small percentage of people going outside of this range.

# %%
# Defines chart size
plt.figure(figsize=(16,5))
# Add title to the chart
plt.title("Total bill vs. tip%", size=25)
# Add x lable to the chart
plt.xlabel("total_bill", size=20)
# Add y lable to the chart
plt.ylabel("Tip%", size=20)
# Plot scatter chart total bill vs. tip%
plt.scatter(x="total_bill",y="tip%", marker="x", c="g", data=tipsdata)
plt.show()

# %% [markdown]
# The above scatter plot evaluates the relationship between the total bill and tip as a percentage of the bill. The main point to notice here is that apart of a few outliers the tip per cent wise doesn't change much with the higher bill and remain in the same range. Meaning that higher bill doen't necessarily correspond to a higher percentage of the tip.

# %% [markdown]
# #### Linear Regression

# %% [markdown]
# In this part **Linear Regression** will be used to determine if and how close relationship between the tip amount and the total bill is.
#
# Linear regression is used for finding linear relationship between target and one or more predictors. There are two types of linear regression:
# * Simple
# * Multiple
#
# Simple linear regression is useful for finding relationship between two continuous variables. One is predictor or independent variable and other is response or dependent variable. It looks for statistical relationship but not deterministic relationship. Relationship between two variables is said to be deterministic if one variable can be accurately expressed by the other. For example, using temperature in degree Celsius it is possible to accurately predict Fahrenheit. Statistical relationship is not accurate in determining relationship between two variables. For example, relationship between height and weight.
#
# The core idea is to obtain a line that best fits the data. The best fit line is the one for which total prediction error (all data points) are as small as possible. Error is the distance between the point to the regression line.
#
# Two main functions in seaborn are used to visualize a linear relationship as determined through regression. These functions, **regplot()** and **lmplot()** are closely related, and share much of their core functionality.
#
# In first step **regplot()** will be used for further investigation. Looking at findings in the previous subsection there will be a tip percentage taken into consideration for this analysis.

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(16,5))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Creates a  regplot with total_bill vs. tip
plt.subplot(1,2,1)
# Add title to the chart
plt.title("Total bill vs.Tip", fontweight="bold", fontsize=15)
# Use regplot from Seaborn and investigate totall_bill and tip variables
sns.regplot(x="total_bill", y="tip", marker="+", color="purple", data=tipsdata);

# Creates a  regplot with total_bill vs. tip%
plt.subplot(1,2,2)
# Add title to the chart
plt.title("Total bill vs.Tip%", fontweight="bold", fontsize=15)
# Use regplot from Seaborn and investigate totall_bill and tip% variables
sns.regplot(x="total_bill", y="tip%", marker="x", color="g", data=tipsdata);
plt.show()

# %% [markdown]
# The **regplot** produced very interesting results for the comparison of variables. On the first chart regression line is ascending together with the amount of total bill and that's why the conclusion is logical and obvious.
# The higher bill is the higher tip is. The second chart delivers descending regression line in relation to the percentage of the tip. This would suggest that a higher bill is the lower percentage of the tip is.
#
# Looking back to the previous section where the total bill against the percentage of the tip was presented on the scatter plot, the tendency wasn't that clearly visible like on regplot.
#
# Another thing to notice is that there are more outliers at the end of the regression line on the tip chart and generally data looks more spread around this line. Comparing tip percentage chart shows that data are more compact and focused around this regresion line.
#
# The regplot drew the regression line of best possible fit on boths plots that describes the relationship between the two pairs of variables and also generated  shadow converging at the centre. This convergent point is actually the statistical mean that predicts the tip value or tip percentage in this restaurant on a daily basis.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ### Analyse<a id="analyse"/>

# %% [markdown]
# In this section the relationships between remaining variables of dataset will be assessed.
# Comming back to very first section of descriptive statitic the findings there reveal that thre are seven variables in this dataset in total.
#
# * total_bill
# * tip
# * sex
# * smoker
# * day
# * time
# * size
#
# Some basic relationship between combination of above variables were also shown in [Data Visualisation](#visualisation) section of this project.
#
# The good starting point of checking other connections or relations between those variables is to use data from the previous section, where the relationship between total bill and tip was evaluated. This time is worth to check how remaining variables in this dataset influence relation between bill and tip.

# %% [markdown]
# #### Smoker - Sex -  Day

# %% [markdown]
# The **relplot** is common choice for visualizing statistical relationships. Using this function is possible to add additional variables and see if there are any connection with total bill and tip.

# %%
# Sets a chart style
sns.set(style="whitegrid", color_codes=True)

# Defines chart size
#plt.figure(figsize=(16,5))


# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Use relplot from Seaborn to add smoker to totall_bill and tip variables
sns.relplot(x="total_bill", y="tip", hue="smoker", col="sex", row="day", palette="Set1", data=tipsdata);
plt.show()

# %% [markdown]
# The above plots include the influence of sex and smoker variables on **total_bill vs. tip** with day consideration.

# %% [markdown]
# #### Size - Time

# %%
# Sets a chart style
sns.set(style="whitegrid", color_codes=True)

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Use relplot from Seaborn to add size and time to totall_bill and tip variables
sns.relplot(x="total_bill", y="tip", hue="time", size="size", col="time", 
            marker="o", palette=["r", "g"], sizes=(10, 100),  data=tipsdata)
plt.show()

# %% [markdown]
# On these charts the influence of size variable on **total_bill vs. tip** with time consideration is visible.

# %% [markdown]
# #### Size - Tip Percentage - Time

# %% [markdown]
# Here another interesting relationship between the size of the guests and the percentage of the tip is presented. To determine between the time of the meal the variable time was included.

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)


# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Present data using catplot
sns.catplot(x="size", y="tip%", col="time", kind="swarm", data=tipsdata);
plt.show()

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(16,5))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})
plt.title("Size vs.Tip% - Regression", fontweight="bold", fontsize=15)
# Use regplot from Seaborn and investigate size and tip% variables
sns.regplot(x="size", y="tip%", marker="+", color="purple", data=tipsdata);

# %% [markdown]
# #### Size - Total Bill

# %% [markdown]
# The next relationship which will be checked is between the total bill and the size of the group.
# It is not a big surprise that total bill increases with the size of party.

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(16,5))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Use Seaborn to display boxplot
sns.boxplot(x="size", y="total_bill", data=tipsdata, palette="Set1")

plt.show()

# %% [markdown]
# #### Time - Tip

# %% [markdown]
# At the end the connection between time and tip is going to be investigated.

# %%
# Sets a chart style
sns.set(style="darkgrid", color_codes=True)

# Defines chart size
plt.figure(figsize=(16,5))

# Defines axes font and lable size 
sns.set_context("paper", font_scale=1.5, rc={"axes.labelsize":16})

# Use Seaborn to display violinplot
sns.violinplot(x="time", y="tip", data=tipsdata, palette="Set1")

plt.show()

# %% [markdown]
# Violin plot above shows that tips are larger during the dinner than lunch time.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ## Summary<a id="summary"/>

# %% [markdown]
# The work and data analysis carried out in this project shows how useful and powerful are Python packages like Pandas and Seaborn. The whole statistical summary on this dataset took no more than a few minutes. Data presentation which uses advance Seaborn graphical interface shows possible rearelationship between variables. This analysis could be done more deeper and detailed however the main goal of this project was focussed on a certain aspect of the dataset. The most important part was related to statistical descriptions of the dataset, check one of the key relationships between the tip and total bill variables, use linear regression and also present those relationships on plots. The last bit of investigation revealed the other possible connections between the remaining variables. This type of analytical work gives an idea how important is to do a right summary on given datasets and check the relationship between all variables to see what exact piece of data could be a useful and what can be done with this type of information.

# %% [markdown]
# [**<<<**](#table)

# %% [markdown]
# ## References<a id="references"/>

# %% [markdown]
# 1. [Kaggle - dataset](https://www.kaggle.com/jsphyg/tipping)
# 1. [Seaborn - analyse data](https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e)
# 1. [Stat Trek - Categorical Variable](https://stattrek.com/statistics/dictionary.aspx?definition=categorical%20variable)
# 1. [Plotting with categorical data](https://seaborn.pydata.org/tutorial/categorical.html)
# 1. [Python Seaborn Tutorial For Beginners](https://www.datacamp.com/community/tutorials/seaborn-python-tutorial)
# 1. [GeeksforGeeks - Correlation function](https://www.geeksforgeeks.org/python-pandas-dataframe-corr/)
# 1. [GeeksforGeeks - Exploring correlation](https://www.geeksforgeeks.org/exploring-correlation-in-python/)
# 1. [Seaborn - Visualizing linear relationships](https://seaborn.pydata.org/tutorial/regression.html)
# 1. [Linear Regression — Detailed View](https://towardsdatascience.com/linear-regression-detailed-view-ea73175f6e86)
# 1. [Data Visualization with Python and Seaborn ](https://medium.com/@neuralnets/data-visualization-with-python-and-seaborn-part-4-9b0119887130)

# %% [markdown]
# [**<<<**](#table)
